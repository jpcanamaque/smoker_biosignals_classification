# %% [markdown]
# <a href="https://colab.research.google.com/github/jpcanamaque/codingdojo-project2/blob/master/Project2_CodingDojo_Proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2 for Data Science Bootcamp
# ## Author: Johnroe Paulo Canamaque

# %%
# Importing needed modules
import pandas as pd

# %% [markdown]
# ## Students' Employability Dataset
#
# **Source of data:**
# - https://www.kaggle.com/datasets/gauravduttakiit/smoker-status-prediction-using-biosignals
#
# **Brief description of data:**
#   - Smoking has been proven to negatively affect health in a multitude of ways.Smoking has been found to harm nearly every organ of the body, cause many diseases, as well as reducing the life expectancy of smokers in general. As of 2018, smoking has been considered the leading cause of preventable morbidity and mortality in the world, continuing to plague the world’s overall health.
#
#   According to a World Health Organization report, the number of deaths caused by smoking will reach 10 million by 2030.
#
#   Evidence-based treatment for assistance in smoking cessation had been proposed and promoted. however, only less than one third of the participants could achieve the goal of abstinence. Many physicians found counseling for smoking cessation ineffective and time-consuming, and did not routinely do so in daily practice. To overcome this problem, several factors had been proposed to identify smokers who had a better chance of quitting, including the level of nicotine dependence, exhaled carbon monoxide (CO) concentration, cigarette amount per day, the age at smoking initiation, previous quit attempts, marital status, emotional distress, temperament and impulsivity scores, and the motivation to stop smoking. However, individual use of these factors for prediction could lead to conflicting results that were not straightforward enough for the physicians and patients to interpret and apply. Providing a prediction model might be a favorable way to understand the chance of quitting smoking for each individual smoker. Health outcome prediction models had been developed using methods of machine learning over recent years.
#
#   A group of scientists are working on predictive models with smoking status as the prediction target.Your task is to help them create a machine learning model to identify the smoking status of an individual using bio-signals
#
# **Target:**
# - `smoking`
#
# **Is this a classification or regression problem?**
# - CLASSIFICATION
#
# **How many features?**
# - 23
#
# **How many rows of data?**
# - 38,984 (training)
# - 16,708 (test)
#
# **What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?**
# - Class data balancing
# - Model selection
# - Feature engineering
# - Timing on the modelling

# %%
# Fetch the data from the data source and assign to a data frame variable
smoker_train_data_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vScgQWdl1UmogQAzMJpOI4tbaZsN0Zsp2GQy4FV_XWdtKZUi1DsEfXKhGlPAd4JChuz8MqWE7zuVyLB/pub?gid=1259380212&single=true&output=csv'
smoker_test_data_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vR1e1JCcNr47PSb_wpX6TRLY7qhE_4eEwsO98VoWqesMG1AZbKFBJdA_O0Mr7eFmX7y_HXzbo9hfjum/pub?gid=1222544153&single=true&output=csv'
st_train_df = pd.read_csv(smoker_train_data_url)
st_test_df = pd.read_csv(smoker_test_data_url)

# %%
# Show first 10 rows on training data
st_train_df.head(10)
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   35         170          85       97.0             0.9              0.9
# 1   20         175         110      110.0             0.7              0.9
# 2   45         155          65       86.0             0.9              0.9
# 3   45         165          80       94.0             0.8              0.7
# 4   20         165          60       81.0             1.5              0.1
# 5   60         160          50       78.0             1.0              0.9
# 6   40         175          90       95.0             0.9              1.0
# 7   40         180          75       85.0             1.5              1.5
# 8   40         170          60       74.0             1.2              1.5
# 9   45         155          55       78.0             0.7              1.0
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  HDL  LDL  \
# 0              1               1       118          78  ...   70  142
# ...

# %%
# Show first 10 rows on test data
st_test_df.head(10)
# Out:
#    age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  eyesight(right)  \
# 0   40         170          65       75.1             1.0              0.9
# 1   45         170          75       89.0             0.7              1.2
# 2   30         180          90       94.0             1.0              0.8
# 3   60         170          50       73.0             0.5              0.7
# 4   30         170          65       78.0             1.5              1.0
# 5   55         175          60       75.0             1.0              1.0
# 6   40         160          55       69.0             1.5              1.5
# 7   55         175          60       80.0             1.2              1.5
# 8   55         160          50       68.0             0.8              0.5
# 9   75         145          50       81.0             0.5              0.5
#
#    hearing(left)  hearing(right)  systolic  relaxation  ...  triglyceride  \
# ...

# %% [markdown]
# ## Students' Employability Dataset
#
# **Source of data:**
# - https://www.kaggle.com/datasets/anashamoutni/students-employability-dataset/data
#
# **Brief description of data:**
# - The dataset was collected from different university agencies in the Philippines. It consists of Mock job Interview Results of 2.982 observations. The dataset collected needs to be normalized and cleaned. The dataset that was collected is compliant with the Data Privacy Act of the Philippines.
#
# **Target:**
# - `CLASS`
#
# **Is this a classification or regression problem?**
# - CLASSIFICATION
#
# **How many features?**
# - 10
#
# **How many rows of data?**
# - 2,982
#
# **What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?**
# - Class data balancing
# - Model selection
# - Feature engineering

# %%
# Fetch the data from the data source and assign to a data frame variable
student_employabity_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSfREKO_6wh1P_M5YKL_q8JLBTJGfJgb6ZT84JNnzjupsg4jKsIehdKqNk7wZ_8AA/pub?gid=465574278&single=true&output=csv'
se_df = pd.read_csv(student_employabity_url)

# %%
# Show first 10 rows
se_df.head(10)
# Out:
#   Name of Student  GENERAL APPEARANCE  MANNER OF SPEAKING  PHYSICAL CONDITION  \
# 0       Student 1                   4                   5                   4
# 1       Student 2                   4                   4                   4
# 2       Student 3                   4                   3                   3
# 3       Student 4                   3                   3                   3
# 4       Student 5                   4                   4                   3
# 5       Student 6                   4                   4                   3
# 6       Student 7                   4                   4                   4
# 7       Student 8                   5                   3                   3
# 8       Student 9                   4                   4                   4
# 9      Student 10                   4                   4                   3
#
#    MENTAL ALERTNESS  SELF-CONFIDENCE  ABILITY TO PRESENT IDEAS  \
# ...
